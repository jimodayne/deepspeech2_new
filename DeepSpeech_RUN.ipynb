# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# !pip install soundfile
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# ...

# %%
# !python /content/drive/My\ Drive/DeepSpeech/test.py /content/drive/My\ Drive/DeepSpeech/check_point /content/drive/My\ Drive/DeepSpeech/test_json.json  /content/drive/My\ Drive/DeepSpeech/log_test.csv
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/DeepSpeech/test.py:42: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/DeepSpeech/model.py:72: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/My Drive/DeepSpeech/model.py:82: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !python /content/drive/My\ Drive/DeepSpeech/test.py /content/drive/My\ Drive/DeepSpeech/check_point /content/drive/My\ Drive/DeepSpeech/json/  /content/drive/My\ Drive/DeepSpeech/log_test.csv

# %%
# !python /content/drive/My\ Drive/DeepSpeech/train.py /content/drive/My\ Drive/DeepSpeech/check_point /content/drive/My\ Drive/DeepSpeech/train_json.json /content/drive/My\ Drive/DeepSpeech/test_json.json /content/drive/My\ Drive/DeepSpeech/log.csv
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/DeepSpeech/train.py:37: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/DeepSpeech/model.py:72: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/My Drive/DeepSpeech/model.py:82: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
